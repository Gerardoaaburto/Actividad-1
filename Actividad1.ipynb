# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diamonds = pd.read_csv('diamonds.csv')
diamonds
# Out:
#        carat        cut color clarity  depth  table   price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2    NaN   58.0  2757.0  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0  2757.0  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
#Identificaremos nulos y outliers para eliminarlos.

# %%
diamondsc=diamonds.copy()

# %%
valores_nulos=diamondsc.isnull().sum()
valores_nulos
# Out:
# carat      3
# cut        0
# color      0
# clarity    0
# depth      2
# table      3
# price      3
# x          1
# y          1
# z          4
# dtype: int64

# %%
diamondsc["carat"]=diamondsc["carat"].fillna(round(diamondsc["carat"].mean(),1))
diamondsc
# Out:
#        carat        cut color clarity  depth  table   price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2    NaN   58.0  2757.0  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0  2757.0  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamondsc["depth"]=diamondsc["depth"].fillna(round(diamondsc["depth"].mean(),1))
diamondsc
# Out:
#        carat        cut color clarity  depth  table   price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.7   58.0  2757.0  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0  2757.0  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamondsc["table"]=diamondsc["table"].fillna(round(diamondsc["table"].mean(),1))
diamondsc
# Out:
#        carat        cut color clarity  depth  table   price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.7   58.0  2757.0  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0  2757.0  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamondsc["price"]=diamondsc["price"].fillna(round(diamondsc["price"].median(),1))
diamondsc
# Out:
#        carat        cut color clarity  depth  table   price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.7   58.0  2757.0  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0  2757.0  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamondsc["x"] =diamondsc["x"].fillna(method="ffill") 
diamondsc
# Out:
#        carat        cut color clarity  depth  table   price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.7   58.0  2757.0  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0  2757.0  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamondsc["y"] =diamondsc["y"].fillna(method="ffill") 
diamondsc
# Out:
#        carat        cut color clarity  depth  table   price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.7   58.0  2757.0  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0  2757.0  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamondsc["z"] =diamondsc["z"].fillna(method="ffill") 
diamondsc
# Out:
#        carat        cut color clarity  depth  table   price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.7   58.0  2757.0  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0  2757.0  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
valores_nulos=diamondsc.isnull().sum()
valores_nulos
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
#Outliers

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=diamondsc
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# /var/folders/_k/y1w3sds95nb7b2qqw5w4hw_00000gn/T/ipykernel_9338/3582065310.py:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# /var/folders/_k/y1w3sds95nb7b2qqw5w4hw_00000gn/T/ipykernel_9338/3582065310.py:3: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# Limite superior permitido carat        2.219953
# depth       66.047217
# table       64.160560
# price    15901.118285
# x            9.096451
# y            9.160930
# z            5.655821
# ...

# %%
outliers= diamondsc[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# /var/folders/_k/y1w3sds95nb7b2qqw5w4hw_00000gn/T/ipykernel_9338/4223154592.py:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers= diamondsc[(y>Limite_Superior)|(y<Limite_Inferior)]
#        carat  cut color clarity  depth  table  price   x   y   z
# 0        NaN  NaN   NaN     NaN    NaN    NaN    NaN NaN NaN NaN
# 1        NaN  NaN   NaN     NaN    NaN    NaN    NaN NaN NaN NaN
# 2        NaN  NaN   NaN     NaN   56.9   65.0    NaN NaN NaN NaN
# 3        NaN  NaN   NaN     NaN    NaN    NaN    NaN NaN NaN NaN
# 4        NaN  NaN   NaN     NaN    NaN    NaN    NaN NaN NaN NaN
# ...      ...  ...   ...     ...    ...    ...    ...  ..  ..  ..
# 53935    NaN  NaN   NaN     NaN    NaN    NaN    NaN NaN NaN NaN
# 53936    NaN  NaN   NaN     NaN    NaN    NaN    NaN NaN NaN NaN
# ...

# %%
#Obtenemos datos sin outliers del DataFrame
dt= diamondsc[(y<=Limite_Superior)&(y>=Limite_Inferior)]
dt
# Out:
# /var/folders/_k/y1w3sds95nb7b2qqw5w4hw_00000gn/T/ipykernel_9338/3360258083.py:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   dt= diamondsc[(y<=Limite_Superior)&(y>=Limite_Inferior)]
#        carat  cut color clarity  depth  table   price     x     y     z
# 0       0.23  NaN   NaN     NaN   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21  NaN   NaN     NaN   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23  NaN   NaN     NaN    NaN    NaN   327.0  4.05  4.07  2.31
# 3       0.29  NaN   NaN     NaN   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31  NaN   NaN     NaN   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...  ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72  NaN   NaN     NaN   60.8   57.0  2757.0  5.75  5.76  3.50
# ...

# %%
#Eliminamos columnas innecesarias
dt= dt.drop(['color'], axis=1)
dt
# Out:
#        carat  cut clarity  depth  table   price     x     y     z
# 0       0.23  NaN     NaN   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21  NaN     NaN   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23  NaN     NaN    NaN    NaN   327.0  4.05  4.07  2.31
# 3       0.29  NaN     NaN   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31  NaN     NaN   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...  ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72  NaN     NaN   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72  NaN     NaN   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70  NaN     NaN   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86  NaN     NaN   61.7   58.0  2757.0  6.15  6.12  3.74
# 53939   0.75  NaN     NaN   62.2   55.0  2757.0  5.83  5.87  3.64
#
# [53940 rows x 9 columns]

# %%
dt= dt.drop(['cut'], axis=1)
dt
# Out:
#        carat clarity  depth  table   price     x     y     z
# 0       0.23     NaN   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21     NaN   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23     NaN    NaN    NaN   327.0  4.05  4.07  2.31
# 3       0.29     NaN   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31     NaN   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72     NaN   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72     NaN   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70     NaN   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86     NaN   61.7   58.0  2757.0  6.15  6.12  3.74
# 53939   0.75     NaN   62.2   55.0  2757.0  5.83  5.87  3.64
#
# [53940 rows x 8 columns]

# %%
dt= dt.drop(['clarity'], axis=1)
dt
# Out:
#        carat  depth  table   price     x     y     z
# 0       0.23   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23    NaN    NaN   327.0  4.05  4.07  2.31
# 3       0.29   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...    ...    ...     ...   ...   ...   ...
# 53935   0.72   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86   61.7   58.0  2757.0  6.15  6.12  3.74
# 53939   0.75   62.2   55.0  2757.0  5.83  5.87  3.64
#
# [53940 rows x 7 columns]

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean=dt.copy()
data_clean=data_clean.fillna(round(dt.mean(),1))
data_clean
# Out:
#        carat  depth  table   price     x     y     z
# 0       0.23   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23   61.7   57.4   327.0  4.05  4.07  2.31
# 3       0.29   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...    ...    ...     ...   ...   ...   ...
# 53935   0.72   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86   61.7   58.0  2757.0  6.15  6.12  3.74
# 53939   0.75   62.2   55.0  2757.0  5.83  5.87  3.64
#
# [53940 rows x 7 columns]

# %%
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# carat    0
# depth    0
# table    0
# price    0
# x        0
# y        0
# z        0
# dtype: int64

# %%
data=data_clean.copy()

# %%
from turtle import color


sns.scatterplot(x='carat', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= data[['carat']]
Var_Dep= data['price']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': 'deprecated',
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['carat'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([6524.37184205]),
#  'rank_': 1,
#  'singular_': array([104.13800591]),
#  'intercept_': -1490.1035867428127}

# %%
#Corroboramos cual es el coeficiente de correlación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.7237425326886817

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.8507305876061362

# %%
from turtle import color


sns.scatterplot(x='depth', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='depth', ylabel='price'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= data[['depth']]
Var_Dep= data['price']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model1= LinearRegression()

# %%
model1.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model1.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': 'deprecated',
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['depth'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-6.26805918]),
#  'rank_': 1,
#  'singular_': array([295.83615478]),
#  'intercept_': 4014.533038765501}

# %%
#Corroboramos cual es el coeficiente de correlación de nuestro modelo
coef_Deter=model1.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 5.390845018937718e-06

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.0023218193338280474

# %%
from turtle import color


sns.scatterplot(x='table', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='table', ylabel='price'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= data[['table']]
Var_Dep= data['price']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': 'deprecated',
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['table'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([208.24785575]),
#  'rank_': 1,
#  'singular_': array([491.13052505]),
#  'intercept_': -8326.837353443494}

# %%
#Corroboramos cual es el coeficiente de correlación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.01639997188443776

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.12806237497578185

# %%
#Carat y depth

# %%
from turtle import color


sns.scatterplot(x='carat', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
from turtle import color


sns.scatterplot(x='depth', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='depth', ylabel='price'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= data[['carat','depth']]
Var_Dep= data['price']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model3= LinearRegression()

# %%
model3.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model3.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': 'deprecated',
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['carat', 'depth'], dtype=object),
#  'n_features_in_': 2,
#  'coef_': array([6525.4067985 ,  -32.23159657]),
#  'rank_': 2,
#  'singular_': array([295.83882763, 104.13041252]),
#  'intercept_': 499.11446884523593}

# %%
#Corroboramos cual es el coeficiente de correlación de nuestro modelo
coef_Deter3=model3.score(X=Vars_Indep, y=Var_Dep)
coef_Deter3
# Out:
# 0.7238850602379927

# %%
coef_Correl3=np.sqrt(coef_Deter3)
coef_Correl3
# Out:
# 0.8508143512176982

# %%
#Carat y table

# %%
from turtle import color


sns.scatterplot(x='carat', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
from turtle import color


sns.scatterplot(x='table', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='table', ylabel='price'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= data[['carat','table']]
Var_Dep= data['price']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model4= LinearRegression()

# %%
model4.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model4.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': 'deprecated',
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['carat', 'table'], dtype=object),
#  'n_features_in_': 2,
#  'coef_': array([6567.82712097,  -49.73845127]),
#  'rank_': 2,
#  'singular_': array([491.52642674, 102.25306216]),
#  'intercept_': 1331.023094599258}

# %%
#Corroboramos cual es el coeficiente de correlación de nuestro modelo
coef_Deter4=model4.score(X=Vars_Indep, y=Var_Dep)
coef_Deter4
# Out:
# 0.724645975286663

# %%
coef_Correl4=np.sqrt(coef_Deter4)
coef_Correl4
# Out:
# 0.8512614024414962

# %%
#Depth y table
from turtle import color
sns.scatterplot(x='depth', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='depth', ylabel='price'>

# %%
from turtle import color


sns.scatterplot(x='table', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='table', ylabel='price'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= data[['depth','table']]
Var_Dep= data['price']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model5= LinearRegression()

# %%
model5.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Corroboramos cual es el coeficiente de correlación de nuestro modelo
coef_Deter5=model5.score(X=Vars_Indep, y=Var_Dep)
coef_Deter5
# Out:
# 0.01759070227527182

# %%
coef_Correl5=np.sqrt(coef_Deter5)
coef_Correl5
# Out:
# 0.13262994486642835

# %%
# tamaño(x, y, z)
from turtle import color
sns.scatterplot(x='x', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='x', ylabel='price'>

# %%
from turtle import color


sns.scatterplot(x='y', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='y', ylabel='price'>

# %%
from turtle import color


sns.scatterplot(x='z', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='z', ylabel='price'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= data[['x','y','z']]
Var_Dep= data['price']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model6= LinearRegression()

# %%
model6.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model6.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': 'deprecated',
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['x', 'y', 'z'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([ -44.86021554, 1916.34808886, 1217.78041141]),
#  'rank_': 3,
#  'singular_': array([397.93890829,  21.25680268,  12.25135503]),
#  'intercept_': -11408.546214863067}

# %%
#Corroboramos cual es el coeficiente de correlación de nuestro modelo
coef_Deter6=model6.score(X=Vars_Indep, y=Var_Dep)
coef_Deter6
# Out:
# 0.7141326759446662

# %%
coef_Correl6=np.sqrt(coef_Deter6)
coef_Correl6
# Out:
# 0.8450637111748831

# %%
# Tamaño, carat y depth

# %%
from turtle import color


sns.scatterplot(x='x', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='x', ylabel='price'>

# %%
from turtle import color


sns.scatterplot(x='y', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='y', ylabel='price'>

# %%
from turtle import color


sns.scatterplot(x='z', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='z', ylabel='price'>

# %%
from turtle import color


sns.scatterplot(x='carat', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
from turtle import color


sns.scatterplot(x='depth', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='depth', ylabel='price'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= data[['x','y','z', 'carat', 'depth']]
Var_Dep= data['price']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model7= LinearRegression()

# %%
model7.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model7.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': 'deprecated',
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['x', 'y', 'z', 'carat', 'depth'], dtype=object),
#  'n_features_in_': 5,
#  'coef_': array([-913.81245001, 1821.83069577,  318.54487861, 3928.45678023,
#           -6.83619386]),
#  'rank_': 5,
#  'singular_': array([410.36544845, 296.20972646,  28.81995993,  14.18753898,
#          12.21462897]),
#  'intercept_': -5365.8910252380065}

# %%
#Corroboramos cual es el coeficiente de correlación de nuestro modelo
coef_Deter7=model7.score(X=Vars_Indep, y=Var_Dep)
coef_Deter7
# Out:
# 0.7352729394544713

# %%
coef_Correl7=np.sqrt(coef_Deter7)
coef_Correl7
# Out:
# 0.8574805767214038

# %%
# Tamaño, carat, depth y table. 
from turtle import color
sns.scatterplot(x='x', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='x', ylabel='price'>

# %%
from turtle import color


sns.scatterplot(x='y', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='y', ylabel='price'>

# %%
from turtle import color


sns.scatterplot(x='z', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='z', ylabel='price'>

# %%
from turtle import color


sns.scatterplot(x='carat', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
from turtle import color


sns.scatterplot(x='depth', y='price', color="blue", data=data)
#sns.scatterplot(x='speeding', y='total', color="red", data=df)
# Out:
# <AxesSubplot:xlabel='depth', ylabel='price'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= data[['x','y','z', 'carat', 'depth', 'table']]
Var_Dep= data['price']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model8= LinearRegression()

# %%
model8.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model8.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': 'deprecated',
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['x', 'y', 'z', 'carat', 'depth', 'table'], dtype=object),
#  'n_features_in_': 6,
#  'coef_': array([-753.30930488, 1705.08732845,  255.46501   , 3966.56797554,
#          -30.30892312,  -58.55029865]),
#  'rank_': 6,
#  'singular_': array([515.2993119 , 393.26930772, 277.77306964,  28.79488437,
#          14.18279341,  12.16408744]),
#  'intercept_': -612.7415950482737}

# %%
#Corroboramos cual es el coeficiente de correlación de nuestro modelo
coef_Deter8=model8.score(X=Vars_Indep, y=Var_Dep)
coef_Deter8
# Out:
# 0.7364132878718476

# %%
coef_Correl8=np.sqrt(coef_Deter8)
coef_Correl8
# Out:
# 0.8581452603562217

# %%
carr_dff=data.corr()
carr_dff
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.011303  0.185252  0.850731  0.957225  0.955947  0.955054
# depth  0.011303  1.000000 -0.277038 -0.002322 -0.031854 -0.033726  0.074943
# table  0.185252 -0.277038  1.000000  0.128062  0.195987  0.190798  0.159840
# price  0.850731 -0.002322  0.128062  1.000000  0.842965  0.844281  0.840173
# x      0.957225 -0.031854  0.195987  0.842965  1.000000  0.997742  0.989128
# y      0.955947 -0.033726  0.190798  0.844281  0.997742  1.000000  0.988673
# z      0.955054  0.074943  0.159840  0.840173  0.989128  0.988673  1.000000

# %%
carr_dff1=abs(carr_dff)
carr_dff1
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.011303  0.185252  0.850731  0.957225  0.955947  0.955054
# depth  0.011303  1.000000  0.277038  0.002322  0.031854  0.033726  0.074943
# table  0.185252  0.277038  1.000000  0.128062  0.195987  0.190798  0.159840
# price  0.850731  0.002322  0.128062  1.000000  0.842965  0.844281  0.840173
# x      0.957225  0.031854  0.195987  0.842965  1.000000  0.997742  0.989128
# y      0.955947  0.033726  0.190798  0.844281  0.997742  1.000000  0.988673
# z      0.955054  0.074943  0.159840  0.840173  0.989128  0.988673  1.000000

# %%
Heat_Map= sns.heatmap(carr_dff1, cmap ='Y!GnBu')
Heat_Map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/cm.py:131, in ColormapRegistry.__getitem__(self, item)
#     130 try:
# --> 131     return self._cmaps[item].copy()
#     132 except KeyError:
#
# KeyError: 'Y1GnBu'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /Users/GAC/Desktop/Actividad 1/Actividad-1/Actividad1.ipynb Celda 104 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/GAC/Desktop/Actividad%201/Actividad-1/Actividad1.ipynb#Y206sZmlsZQ%3D%3D?line=0'>1</a> Heat_Map= sns.heatmap(carr_dff1, cmap ='Y1GnBu')
#       <a href='vscode-notebook-cell:/Users/GAC/Desktop/Actividad%201/Actividad-1/Actividad1.ipynb#Y206sZmlsZQ%3D%3D?line=1'>2</a> Heat_Map
#
# ...
